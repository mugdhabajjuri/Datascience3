# %%
import pandas as pd
df_ids = pd.read_csv('../notebooks/processed.csv')
df_ids.head()
# Out:
#    Unnamed: 0  movieId  imdbId  tmdbId             title  \
# 0           0        1  114709   862.0  Toy Story (1995)
# 1           1        1  114709   862.0  Toy Story (1995)
# 2           2        1  114709   862.0  Toy Story (1995)
# 3           3        1  114709   862.0  Toy Story (1995)
# 4           4        1  114709   862.0  Toy Story (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy
#
#                                           genre_list Movie Title    year  \
# 0  ['Adventure', 'Animation', 'Children', 'Comedy...  Toy Story   1995.0
# 1  ['Adventure', 'Animation', 'Children', 'Comedy...  Toy Story   1995.0
# 2  ['Adventure', 'Animation', 'Children', 'Comedy...  Toy Story   1995.0
# ...

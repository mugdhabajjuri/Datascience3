# %%
import pandas as pd
df_ids = pd.read_csv('../data/raw/links.csv')
df_ids.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movies = pd.read_csv('../data/raw/movies.csv')
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings = pd.read_csv('../data/raw/ratings.csv')
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_tags = pd.read_csv('../data/raw/tags.csv')
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
#combining the dataframes df_ratings and df_tags on the common columns
df_merge = pd.merge(df_ratings, df_tags,  how='outer', left_on=['userId','movieId','timestamp'], right_on = ['userId','movieId','timestamp'])

# %%
df_merge.head()
# Out:
#    userId  movieId  rating  timestamp  tag
# 0       1        1     4.0  964982703  NaN
# 1       1        3     4.0  964981247  NaN
# 2       1        6     4.0  964982224  NaN
# 3       1       47     5.0  964983815  NaN
# 4       1       50     5.0  964982931  NaN

# %%
#combining all the 3 dataframes into one
from functools import reduce
dfs = [df_ids, df_movies, df_merge]
df = reduce(lambda left,right: pd.merge(left,right,on='movieId'), dfs)

# %%
df.head()
# Out:
#    movieId  imdbId  tmdbId             title  \
# 0        1  114709   862.0  Toy Story (1995)
# 1        1  114709   862.0  Toy Story (1995)
# 2        1  114709   862.0  Toy Story (1995)
# 3        1  114709   862.0  Toy Story (1995)
# 4        1  114709   862.0  Toy Story (1995)
#
#                                         genres  userId  rating   timestamp  \
# 0  Adventure|Animation|Children|Comedy|Fantasy       1     4.0   964982703
# 1  Adventure|Animation|Children|Comedy|Fantasy       5     4.0   847434962
# 2  Adventure|Animation|Children|Comedy|Fantasy       7     4.5  1106635946
# 3  Adventure|Animation|Children|Comedy|Fantasy      15     2.5  1510577970
# 4  Adventure|Animation|Children|Comedy|Fantasy      17     4.5  1305696483
#
#    tag
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df['movieId']=69

# %%
df
# Out:
#         movieId   imdbId    tmdbId  \
# 0            69   114709     862.0
# 1            69   114709     862.0
# 2            69   114709     862.0
# 3            69   114709     862.0
# 4            69   114709     862.0
# 5            69   114709     862.0
# 6            69   114709     862.0
# 7            69   114709     862.0
# 8            69   114709     862.0
# 9            69   114709     862.0
# 10           69   114709     862.0
# 11           69   114709     862.0
# 12           69   114709     862.0
# 13           69   114709     862.0
# 14           69   114709     862.0
# 15           69   114709     862.0
# 16           69   114709     862.0
# 17           69   114709     862.0
# 18           69   114709     862.0
# 19           69   114709     862.0
# 20           69   114709     862.0
# 21           69   114709     862.0
# 22           69   114709     862.0
# 23           69   114709     862.0
# 24           69   114709     862.0
# ...

# %%
df.to_csv('final.csv')

# %%
df['movieId'].nunique()
# Out:
# 1

# %%
df['genres'].nunique()
# Out:
# 951

# %%
#rslt_df = df.loc[df['rating'] >= 4.0]

# %%
#movies = rslt_df.groupby('movieId')
#df2 = movies.mean().reset_index(name='moviereview')

# %%
#df3 = df.groupby('movieId')['rating'].mean()

# %%
df.head()
# Out:
#    movieId  imdbId  tmdbId             title  \
# 0       69  114709   862.0  Toy Story (1995)
# 1       69  114709   862.0  Toy Story (1995)
# 2       69  114709   862.0  Toy Story (1995)
# 3       69  114709   862.0  Toy Story (1995)
# 4       69  114709   862.0  Toy Story (1995)
#
#                                         genres  userId  rating   timestamp  \
# 0  Adventure|Animation|Children|Comedy|Fantasy       1     4.0   964982703
# 1  Adventure|Animation|Children|Comedy|Fantasy       5     4.0   847434962
# 2  Adventure|Animation|Children|Comedy|Fantasy       7     4.5  1106635946
# 3  Adventure|Animation|Children|Comedy|Fantasy      15     2.5  1510577970
# 4  Adventure|Animation|Children|Comedy|Fantasy      17     4.5  1305696483
#
#    tag
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df3 = df.loc[df['genres'] == 'Adventure|Animation|Children|Comedy|Fantasy' & df['rating'] == 1.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# ...

# %%
df3.shape
# Out:
# (585, 9)

# %%
df3['title'].unique()
# Out:
# array(['Toy Story (1995)', 'Antz (1998)', 'Toy Story 2 (1999)',
#        'Adventures of Rocky and Bullwinkle, The (2000)',
#        "Emperor's New Groove, The (2000)", 'Monsters, Inc. (2001)',
#        'Wild, The (2006)', 'Shrek the Third (2007)',
#        'Tale of Despereaux, The (2008)',
#        'Asterix and the Vikings (Astérix et les Vikings) (2006)',
#        'Turbo (2013)', 'The Good Dinosaur (2015)', 'Moana (2016)'],
#       dtype=object)
